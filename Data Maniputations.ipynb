# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import os
plt.rcParams["figure.figsize"] = (20,10)

# %%
os.chdir ("C:\\Users\\Ayesha Bagwan\\OneDrive\\CS 21 Ans -Data Maniputations-1")

df = pd.read_csv('HollywoodMovies.csv', delimiter=',')
display (df)
# Out:
#                                          Movie              LeadStudio  \
# 0                                 Spider-Man 3                    Sony
# 1                              Shrek the Third               Paramount
# 2                                 Transformers               Paramount
# 3     Pirates of the Caribbean: At World's End                  Disney
# 4    Harry Potter and the Order of the Phoenix             Warner Bros
# ..                                         ...                     ...
# 965                                The Canyons                     IFC
# 966                                   The Call                 TriStar
# 967                        The English Teacher  Cinedigm Entertainment
# 968                       John Dies at the End                Magnolia
# 969                                   Lovelace              Radius-TWC
#
#      RottenTomatoes  AudienceScore          Story      Genre  \
# 0              61.0           54.0  Metamorphosis     Action
# 1              42.0           57.0          Quest  Animation
# 2              57.0           89.0  Monster Force     Action
# 3              45.0           74.0         Rescue     Action
# 4              78.0           82.0          Quest  Adventure
# ..              ...            ...            ...        ...
# 965            22.0            NaN            NaN        NaN
# 966            43.0           66.0            NaN        NaN
# 967            42.0            NaN            NaN        NaN
# 968            61.0           53.0            NaN        NaN
# 969            55.0           37.0            NaN  Biography
#
#      TheatersOpenWeek  OpeningWeekend  BOAvgOpenWeekend  DomesticGross  \
# 0              4252.0          151.10           35540.0         336.53
# 1              4122.0          121.60           29507.0         322.72
# 2              4011.0           70.50           17577.0         319.25
# 3              4362.0          114.70           26302.0         309.42
# 4              4285.0           77.10           17998.0         292.00
# ..                ...             ...               ...            ...
# 965               1.0            0.01           13351.0           0.06
# 966            2507.0           17.12            6828.0          51.87
# 967               2.0            0.01            3001.0           0.10
# 968               1.0            0.01           12467.0           0.14
# 969             118.0            0.18            1564.0           0.36
#
#      ForeignGross  WorldGross  Budget  Profitability  OpenProfit  Year
# 0          554.34      890.87   258.0         345.30       58.57  2007
# 1          476.24      798.96   160.0         499.35       76.00  2007
# 2          390.46      709.71   150.0         473.14       47.00  2007
# 3          654.00      963.42   300.0         321.14       38.23  2007
# 4          647.88      939.89   150.0         626.59       51.40  2007
# ..            ...         ...     ...            ...         ...   ...
# 965          0.14        0.19     NaN          77.21         NaN  2013
# 966         16.70       68.57    13.0         527.48      131.69  2013
# 967          0.06        0.10     NaN            NaN         NaN  2013
# 968           NaN        0.14     1.0          14.20        1.00  2013
# 969          1.17        1.52    10.0          15.25        1.80  2013
#
# [970 rows x 16 columns]

# %%
selected_columns = df.loc[:, ["Movie", "AudienceScore", "Story"]]
highest_rated = ""
rating = 0

for i in range(0, 970):
    if selected_columns.loc[i]["Story"] in ("Quest","quest") and selected_columns.loc[i]["AudienceScore"] > rating:
        rating = selected_columns.loc[i]["AudienceScore"]
        highest_rated = selected_columns.loc[i]["Movie"]

print(highest_rated,'-', rating)
# Out:
# Into the Wild - 90.0

# %%
genre = df.loc[:, ["Genre"]]

frequency = dict()

for i in range(0, 970):
    if genre.iloc[i, 0] in frequency:
        frequency[str(genre.iloc[i, 0])] += 1
    else:
        frequency[str(genre.iloc[i, 0])] = 1

print(frequency)
# Out:
# {'Action': 166, 'Animation': 51, 'Adventure': 30, 'Thriller': 35, 'Comedy': 177, 'Musical': 4, 'Drama': 109, 'Biography': 14, 'Horror': 52, 'Romance': 20, 'Fantasy': 6, 'Documentary': 7, 'Crime': 15, 'nan': 1, 'Mystery': 5}

# %%
frequency_sorted = sorted(frequency.items(), key=lambda x: x[1], reverse=True)

print (frequency_sorted)
# Out:
# [('Comedy', 177), ('Action', 166), ('Drama', 109), ('Horror', 52), ('Animation', 51), ('Thriller', 35), ('Adventure', 30), ('Romance', 20), ('Crime', 15), ('Biography', 14), ('Documentary', 7), ('Fantasy', 6), ('Mystery', 5), ('Musical', 4), ('nan', 1)]

# %%
for i in frequency_sorted:
	print(i[0],'-' ,i[1])
# Out:
# Comedy - 177
# Action - 166
# Drama - 109
# Horror - 52
# Animation - 51
# Thriller - 35
# Adventure - 30
# Romance - 20
# Crime - 15
# Biography - 14
# Documentary - 7
# Fantasy - 6
# Mystery - 5
# Musical - 4
# nan - 1

# %%
print (frequency_sorted[0])
# Out:
# ('Comedy', 177)

# %%
top5budget = df.sort_values(by='Budget', ascending=False)
top5budget[['Movie','Budget']].head()
# Out:
#                                         Movie  Budget
# 3    Pirates of the Caribbean: At World's End   300.0
# 468                                   Tangled   260.0
# 0                                Spider-Man 3   258.0
# 710                               John Carter   250.0
# 778                     The Dark Knight Rises   250.0

# %%
selected = df.loc[:, ["Profitability", "RottenTomatoes"]]

plt.scatter(selected["Profitability"], selected["RottenTomatoes"])
plt.xlim(0, 200)
plt.xlabel('Profitability')
plt.ylabel('Rating')
plt.show()

# %%
import pandas as pd

raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
        'last_name': ['Miller', 'Jacobson', ".", 'Milner', 'Cooze'],
        'age': [42, 52, 36, 24, 73],
        'preTestScore': [4, 24, 31, ".", "."],
        'postTestScore': ["25,000", "94,000", 57, 62, 70]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'preTestScore', 'postTestScore'])
print(df)
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Milner   24            .            62
# 4        Amy     Cooze   73            .            70

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
        'last_name': ['Miller', 'Jacobson', ".", 'Milner', 'Cooze'],
        'age': [42, 52, 36, 24, 73],
        'preTestScore': [4, 24, 31, ".", "."],
        'postTestScore': ["25,000", "94,000", 57, 62, 70]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'preTestScore', 'postTestScore'])
df.to_csv('example.csv')

# %%
df = pd.read_csv('example.csv')
print(df)
# Out:
#    Unnamed: 0 first_name last_name  age preTestScore postTestScore
# 0           0      Jason    Miller   42            4        25,000
# 1           1      Molly  Jacobson   52           24        94,000
# 2           2       Tina         .   36           31            57
# 3           3       Jake    Milner   24            .            62
# 4           4        Amy     Cooze   73            .            70

# %%
import pandas as pd
df = pd.read_csv('example.csv', header=None)
print(df)
# Out:
#      0           1          2    3             4              5
# 0  NaN  first_name  last_name  age  preTestScore  postTestScore
# 1  0.0       Jason     Miller   42             4         25,000
# 2  1.0       Molly   Jacobson   52            24         94,000
# 3  2.0        Tina          .   36            31             57
# 4  3.0        Jake     Milner   24             .             62
# 5  4.0         Amy      Cooze   73             .             70

# %%
df = pd.read_csv('example.csv', index_col=['First Name', 'Last Name'], names=['UID', 'First Name', 'Last Name', 'Age', 'Pre-Test Score', 'Post-Test Score'])
print(df)
# Out:
#                       UID  Age Pre-Test Score Post-Test Score
# First Name Last Name
# first_name last_name  NaN  age   preTestScore   postTestScore
# Jason      Miller     0.0   42              4          25,000
# Molly      Jacobson   1.0   52             24          94,000
# Tina       .          2.0   36             31              57
# Jake       Milner     3.0   24              .              62
# Amy        Cooze      4.0   73              .              70

# %%
df = pd.read_csv('example.csv', na_values=['.'])
print(pd.isnull(df))
# Out:
#    Unnamed: 0  first_name  last_name    age  preTestScore  postTestScore
# 0       False       False      False  False         False          False
# 1       False       False      False  False         False          False
# 2       False       False       True  False         False          False
# 3       False       False      False  False          True          False
# 4       False       False      False  False          True          False

# %%
df = pd.read_csv('example.csv', skiprows=3)
print(df)
# Out:
#    2  Tina       .  36 31  57
# 0  3  Jake  Milner  24  .  62
# 1  4   Amy   Cooze  73  .  70

# %%
df = pd.read_csv('example.csv',  thousands=',')
print(df)
# Out:
#    Unnamed: 0 first_name last_name  age preTestScore  postTestScore
# 0           0      Jason    Miller   42            4          25000
# 1           1      Molly  Jacobson   52           24          94000
# 2           2       Tina         .   36           31             57
# 3           3       Jake    Milner   24            .             62
# 4           4        Amy     Cooze   73            .             70

# %%
s = pd.Series(['Amit', 'Bob', 'Kate', 'A', 'b', np.nan, 'Car', 'dog', 'cat'])
print(s.str.lower())
# Out:
# 0    amit
# 1     bob
# 2    kate
# 3       a
# 4       b
# 5     NaN
# 6     car
# 7     dog
# 8     cat
# dtype: object

# %%
s = pd.Series(['Amit', 'Bob', 'Kate', 'A', 'b', np.nan, 'Car', 'dog', 'cat'])
print(s.str.upper())
# Out:
# 0    AMIT
# 1     BOB
# 2    KATE
# 3       A
# 4       B
# 5     NaN
# 6     CAR
# 7     DOG
# 8     CAT
# dtype: object

# %%
s = pd.Series(['Amit', 'Bob', 'Kate', 'A', 'b', np.nan, 'Car', 'dog', 'cat'])
print(s.str.len())
# Out:
# 0    4.0
# 1    3.0
# 2    4.0
# 3    1.0
# 4    1.0
# 5    NaN
# 6    3.0
# 7    3.0
# 8    3.0
# dtype: float64

# %%
s = pd.Index([' Atul', 'John ', ' jack ', 'Sam'])
print(s.str.strip())
# Out:
# Index(['Atul', 'John', 'jack', 'Sam'], dtype='object')

# %%
s = pd.Index([' Atul', 'John ', ' jack ', 'Sam'])
print(s.str.lstrip())
# Out:
# Index(['Atul', 'John ', 'jack ', 'Sam'], dtype='object')

# %%
s = pd.Index([' Atul', 'John ', ' jack ', 'Sam'])
print(s.str.rstrip())
# Out:
# Index([' Atul', 'John', ' jack', 'Sam'], dtype='object')

# %%
s = pd.Series(['India_is_big', 'Population_is_huge', np.nan, 'Has_diverse_culture'])
print(s.str.split('_'))
# Out:
# 0           [India, is, big]
# 1     [Population, is, huge]
# 2                        NaN
# 3    [Has, diverse, culture]
# dtype: object

# %%
s = pd.Series(['India_is_big', 'Population_is_huge', np.nan, 'Has_diverse_culture'])
print(s.str.split('_').str.get(1))
# Out:
# 0         is
# 1         is
# 2        NaN
# 3    diverse
# dtype: object

# %%
s = pd.Series(['India_is_big', 'Population_is_huge', np.nan, 'Has_diverse_culture'])
print(s.str.split('_', expand=True))
# Out:
#             0        1        2
# 0       India       is      big
# 1  Population       is     huge
# 2         NaN      NaN      NaN
# 3         Has  diverse  culture

# %%
import pandas as pd
import numpy as np

s = pd.Series(['A', 'B', 'C', 'AabX', 'BacX','', np.nan, 'CABA', 'dog', 'cat'])
print (s)
print(s.str.replace('^.a|dog', 'XX-XX ', case=False))
# Out:
# 0       A
# 1       B
# 2       C
# 3    AabX
# 4    BacX
# 5
# 6     NaN
# 7    CABA
# 8     dog
# 9     cat
# dtype: object
# 0       A
# 1       B
# 2       C
# 3    AabX
# 4    BacX
# 5
# 6     NaN
# 7    CABA
# 8     dog
# 9     cat
# dtype: object

# %%
d = pd.Series(['12', '-$10', '$10,000'])
print(d.str.replace('$', ''))
# Out:
# 0        12
# 1       -10
# 2    10,000
# dtype: object

# %%
pattern = r'[a-z]+'
replacement = lambda m: m.group(0)[::-1]
s = pd.Series(['india 1998', 'inDia','big country', np.nan])
print (s)

s=s.str.replace(pattern, replacement,regex=True)
print(s)
# Out:
# 0     india 1998
# 1          inDia
# 2    big country
# 3            NaN
# dtype: object
# 0     aidni 1998
# 1          niDai
# 2    gib yrtnuoc
# 3            NaN
# dtype: object

# %%
pattern = r'[0-9][a-z]'
print(pd.Series(['1', '2', '1a', '2b', '2003c']).str.contains(pattern))
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
pattern = r'[0-9][a-z]'

print(pd.Series(['1', '2', '1a', '2b', 'America', 'VietnAm','vietnam', '2003c']).str.contains('A', na=False))
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# dtype: bool

# %%
s = pd.Series(['a', 'a|b', np.nan, 'a|c'])
print(s.str.get_dummies(sep='|'))
# Out:
#    a  b  c
# 0  1  0  0
# 1  1  1  0
# 2  0  0  0
# 3  1  0  1

# %%
left = pd.DataFrame({'key': ['One', 'Two'], 'ltable': [1, 2]})
right = pd.DataFrame({'key': ['One', 'Two'], 'rtable': [4, 5]})
new=pd.merge(left, right, on='key')
print(new)
# Out:
#    key  ltable  rtable
# 0  One       1       4
# 1  Two       2       5

# %%
left = pd.DataFrame({'key': ['One', 'Two'], 'ltable': [1, 2]})
right = pd.DataFrame({'key': ['One', 'Two'], 'rtable': [4, 5]})
new=pd.merge(left, right, on='key')
print(new)
# Out:
#    key  ltable  rtable
# 0  One       1       4
# 1  Two       2       5

# %%
pattern = r'[a-z]+'
replacement = lambda m: m.group(0)[::-1]
s = pd.Series(['india 1998', 'inDia','big country', np.nan])
print (s)
# Out:
# 0     india 1998
# 1          inDia
# 2    big country
# 3            NaN
# dtype: object

# %%
s=s.str.replace(pattern, replacement,regex=True)
print(s)
# Out:
# 0     aidni 1998
# 1          niDai
# 2    gib yrtnuoc
# 3            NaN
# dtype: object

# %%
pip install jupyter_contrib_nbextensions
# Out:
# Collecting jupyter_contrib_nbextensions
#   Downloading jupyter_contrib_nbextensions-0.7.0.tar.gz (23.5 MB)
#      ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#      ---------------------------------------- 0.3/23.5 MB ? eta -:--:--
#       --------------------------------------- 0.5/23.5 MB 1.1 MB/s eta 0:00:21
#      - -------------------------------------- 0.8/23.5 MB 1.0 MB/s eta 0:00:23
#      - -------------------------------------- 1.0/23.5 MB 1.2 MB/s eta 0:00:19
#      -- ------------------------------------- 1.3/23.5 MB 1.1 MB/s eta 0:00:20
#      -- ------------------------------------- 1.6/23.5 MB 1.2 MB/s eta 0:00:20
#      -- ------------------------------------- 1.6/23.5 MB 1.2 MB/s eta 0:00:20
#      ---- ----------------------------------- 2.4/23.5 MB 1.4 MB/s eta 0:00:16
#      ---- ----------------------------------- 2.4/23.5 MB 1.4 MB/s eta 0:00:16
#      ---- ----------------------------------- 2.6/23.5 MB 1.2 MB/s eta 0:00:18
#      ---- ----------------------------------- 2.6/23.5 MB 1.2 MB/s eta 0:00:18
#      ---- ----------------------------------- 2.6/23.5 MB 1.2 MB/s eta 0:00:18
#      ----- ---------------------------------- 3.1/23.5 MB 1.1 MB/s eta 0:00:19
#      ----- ---------------------------------- 3.4/23.5 MB 1.1 MB/s eta 0:00:18
#      ------ --------------------------------- 3.7/23.5 MB 1.1 MB/s eta 0:00:18
#      ------ --------------------------------- 3.9/23.5 MB 1.1 MB/s eta 0:00:18
#      ------ --------------------------------- 3.9/23.5 MB 1.1 MB/s eta 0:00:18
#      ------- -------------------------------- 4.2/23.5 MB 1.1 MB/s eta 0:00:18
#      ------- -------------------------------- 4.5/23.5 MB 1.1 MB/s eta 0:00:18
#      ------- -------------------------------- 4.5/23.5 MB 1.1 MB/s eta 0:00:18
#      ------- -------------------------------- 4.5/23.5 MB 1.1 MB/s eta 0:00:18
#      -------- ------------------------------- 5.0/23.5 MB 1.0 MB/s eta 0:00:18
#      -------- ------------------------------- 5.0/23.5 MB 1.0 MB/s eta 0:00:18
#      --------- ------------------------------ 5.5/23.5 MB 1.0 MB/s eta 0:00:18
#      --------- ------------------------------ 5.8/23.5 MB 1.1 MB/s eta 0:00:17
#      ---------- ----------------------------- 6.0/23.5 MB 1.1 MB/s eta 0:00:17
#      ----------- ---------------------------- 6.6/23.5 MB 1.1 MB/s eta 0:00:16
#      ----------- ---------------------------- 6.8/23.5 MB 1.1 MB/s eta 0:00:15
#      ------------ --------------------------- 7.1/23.5 MB 1.1 MB/s eta 0:00:15
#      ------------ --------------------------- 7.6/23.5 MB 1.2 MB/s eta 0:00:14
#      ------------- -------------------------- 8.1/23.5 MB 1.2 MB/s eta 0:00:13
#      -------------- ------------------------- 8.4/23.5 MB 1.2 MB/s eta 0:00:13
#      --------------- ------------------------ 8.9/23.5 MB 1.2 MB/s eta 0:00:12
#      --------------- ------------------------ 9.2/23.5 MB 1.2 MB/s eta 0:00:12
#      ---------------- ----------------------- 9.4/23.5 MB 1.3 MB/s eta 0:00:12
#      ---------------- ----------------------- 10.0/23.5 MB 1.3 MB/s eta 0:00:11
#      ----------------- ---------------------- 10.2/23.5 MB 1.3 MB/s eta 0:00:11
#      ------------------ --------------------- 10.7/23.5 MB 1.3 MB/s eta 0:00:10
#      ------------------- -------------------- 11.3/23.5 MB 1.3 MB/s eta 0:00:10
#      ------------------- -------------------- 11.5/23.5 MB 1.3 MB/s eta 0:00:09
#      -------------------- ------------------- 12.1/23.5 MB 1.3 MB/s eta 0:00:09
#      --------------------- ------------------ 12.3/23.5 MB 1.4 MB/s eta 0:00:09
#      --------------------- ------------------ 12.6/23.5 MB 1.3 MB/s eta 0:00:09
#      ---------------------- ----------------- 13.1/23.5 MB 1.4 MB/s eta 0:00:08
#      ---------------------- ----------------- 13.4/23.5 MB 1.4 MB/s eta 0:00:08
#      ----------------------- ---------------- 13.9/23.5 MB 1.4 MB/s eta 0:00:07
#      ------------------------ --------------- 14.2/23.5 MB 1.4 MB/s eta 0:00:07
#      ------------------------- -------------- 14.7/23.5 MB 1.4 MB/s eta 0:00:07
#      ------------------------- -------------- 14.9/23.5 MB 1.4 MB/s eta 0:00:07
#      ------------------------- -------------- 15.2/23.5 MB 1.4 MB/s eta 0:00:06
#      -------------------------- ------------- 15.7/23.5 MB 1.4 MB/s eta 0:00:06
#      --------------------------- ------------ 16.0/23.5 MB 1.4 MB/s eta 0:00:06
#      ---------------------------- ----------- 16.5/23.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------- ----------- 16.8/23.5 MB 1.5 MB/s eta 0:00:05
#      ----------------------------- ---------- 17.3/23.5 MB 1.4 MB/s eta 0:00:05
#      ----------------------------- ---------- 17.6/23.5 MB 1.5 MB/s eta 0:00:05
#      ------------------------------ --------- 17.8/23.5 MB 1.5 MB/s eta 0:00:04
#      ------------------------------- -------- 18.4/23.5 MB 1.5 MB/s eta 0:00:04
#      -------------------------------- ------- 18.9/23.5 MB 1.5 MB/s eta 0:00:04
#      -------------------------------- ------- 19.1/23.5 MB 1.5 MB/s eta 0:00:03
#      --------------------------------- ------ 19.7/23.5 MB 1.5 MB/s eta 0:00:03
#      ---------------------------------- ----- 20.2/23.5 MB 1.5 MB/s eta 0:00:03
#      ----------------------------------- ---- 20.7/23.5 MB 1.5 MB/s eta 0:00:02
#      ----------------------------------- ---- 21.0/23.5 MB 1.5 MB/s eta 0:00:02
#      ------------------------------------ --- 21.5/23.5 MB 1.5 MB/s eta 0:00:02
#      ------------------------------------ --- 21.5/23.5 MB 1.5 MB/s eta 0:00:02
#      ------------------------------------- -- 22.0/23.5 MB 1.5 MB/s eta 0:00:01
#      -------------------------------------- - 22.5/23.5 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  23.1/23.5 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  23.3/23.5 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------- 23.5/23.5 MB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ipython_genutils (from jupyter_contrib_nbextensions)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting jupyter_contrib_core>=0.3.3 (from jupyter_contrib_nbextensions)
#   Downloading jupyter_contrib_core-0.4.2.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: jupyter_core in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (5.7.2)
# Collecting jupyter_highlight_selected_word>=0.1.1 (from jupyter_contrib_nbextensions)
#   Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl.metadata (730 bytes)
# Collecting jupyter_nbextensions_configurator>=0.4.0 (from jupyter_contrib_nbextensions)
#   Downloading jupyter_nbextensions_configurator-0.6.4-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: nbconvert>=6.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (7.16.6)
# Requirement already satisfied: notebook>=6.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (7.3.2)
# Requirement already satisfied: tornado in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (6.5.1)
# Requirement already satisfied: traitlets>=4.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (5.14.3)
# Requirement already satisfied: lxml in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (5.3.0)
# Requirement already satisfied: setuptools in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (72.1.0)
# Requirement already satisfied: jupyter-server in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.15.0)
# Requirement already satisfied: pyyaml in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.10.4)
# Requirement already satisfied: packaging in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.19.1)
# Requirement already satisfied: webencodings in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.4.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (308)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (8.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (26.2.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.23.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.22.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.4 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (4.3.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.5)
# Requirement already satisfied: babel>=2.10 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.9.25)
# Requirement already satisfied: requests>=2.31 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: certifi in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (8.30.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: psutil in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.0)
# Requirement already satisfied: decorator in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: colorama in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.2.1)
# Requirement already satisfied: rfc3339-validator in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions)
#   Downloading webcolors-25.10.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.3.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: executing in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\ayesha bagwan\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Downloading jupyter_nbextensions_configurator-0.6.4-py2.py3-none-any.whl (466 kB)
# Downloading webcolors-25.10.0-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: jupyter_contrib_nbextensions, jupyter_contrib_core
#   Building wheel for jupyter_contrib_nbextensions (setup.py): started
#   Building wheel for jupyter_contrib_nbextensions (setup.py): finished with status 'done'
#   Created wheel for jupyter_contrib_nbextensions: filename=jupyter_contrib_nbextensions-0.7.0-py2.py3-none-any.whl size=23428789 sha256=11be8a27a03bd654d73d705e236e5b7839ca620dbcb4dddecb6ea353d2a41b79
#   Stored in directory: c:\users\ayesha bagwan\appdata\local\pip\cache\wheels\d9\79\80\be70fb5a8ce193c55b0238155c4c9122d87c96d93babb03204
#   Building wheel for jupyter_contrib_core (setup.py): started
#   Building wheel for jupyter_contrib_core (setup.py): finished with status 'done'
#   Created wheel for jupyter_contrib_core: filename=jupyter_contrib_core-0.4.2-py2.py3-none-any.whl size=17490 sha256=08d512ff6f651179169104e787394d537fb4f23bb16b2460ae7d5efdef7d2bbe
#   Stored in directory: c:\users\ayesha bagwan\appdata\local\pip\cache\wheels\c6\b5\9a\e53b3fc244703676b874e9be46dc2f9c42d7dcc4792b6716f2
# Successfully built jupyter_contrib_nbextensions jupyter_contrib_core
# Installing collected packages: jupyter_highlight_selected_word, ipython_genutils, webcolors, uri-template, fqdn, isoduration, jupyter_contrib_core, jupyter_nbextensions_configurator, jupyter_contrib_nbextensions
#
#    ---- ----------------------------------- 1/9 [ipython_genutils]
#    ------------- -------------------------- 3/9 [uri-template]
#    ---------------------- ----------------- 5/9 [isoduration]
#    ---------------------------- ------- 7/9 [jupyter_nbextensions_configurator]
#    ----------------------------------- ---- 8/9 [jupyter_contrib_nbextensions]
#    ----------------------------------- ---- 8/9 [jupyter_contrib_nbextensions]
#    ----------------------------------- ---- 8/9 [jupyter_contrib_nbextensions]
#    ----------------------------------- ---- 8/9 [jupyter_contrib_nbextensions]
#    ----------------------------------- ---- 8/9 [jupyter_contrib_nbextensions]
#    ----------------------------------- ---- 8/9 [jupyter_contrib_nbextensions]
#    ----------------------------------- ---- 8/9 [jupyter_contrib_nbextensions]
#    ----------------------------------- ---- 8/9 [jupyter_contrib_nbextensions]
#    ---------------------------------------- 9/9 [jupyter_contrib_nbextensions]
#
# Successfully installed fqdn-1.5.1 ipython_genutils-0.2.0 isoduration-20.11.0 jupyter_contrib_core-0.4.2 jupyter_contrib_nbextensions-0.7.0 jupyter_highlight_selected_word-0.2.0 jupyter_nbextensions_configurator-0.6.4 uri-template-1.3.0 webcolors-25.10.0
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'jupyter_contrib_nbextensions' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'jupyter_contrib_nbextensions'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   DEPRECATION: Building 'jupyter_contrib_core' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'jupyter_contrib_core'. Discussion can be found at https://github.com/pypa/pip/issues/6334
